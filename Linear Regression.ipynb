# %% [markdown]
# # Simple Linear Regression(Predict Pizza price)

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x = [[6], [8], [10], [14], [18]]
y = [[7], [9], [13], [17.5], [18]]
model= LinearRegression()
model.fit(x,y)
plt.figure()
plt.title("Pizza price prediction")
plt.xlabel('pizza size')
plt.ylabel('Price in dollars')
plt.axis([0,25,0,25])
plt.grid(True)
plt.plot(x,y,'*')
plt.plot(x,model.predict(x))
plt.show()
print('predicted prize',model.predict([[6]]))
# Out:
# predicted prize [[7.82327586]]
